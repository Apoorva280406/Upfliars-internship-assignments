# %% [markdown]
# 7. Read a CSV file (you may create it manually) containing product sales
# data with columns: Product, Category, Sales, Region. Perform:
# • Group by Category and calculate total Sales using groupby() and agg()
# • Find the top 3 products by sales using sort_values() and head()

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sales_data.csv")
print(df)
groups = df.groupby("Category")
groups.groups
df.groupby("Category")["Sales"].agg(["sum"])
df.sort_values("Sales")
print("Top 3 products:\n", df.head(3))
# Out:
#          Product       Category  Sales Region
# 0         Laptop    Electronics  50000  North
# 1         Mobile    Electronics  30000  South
# 2             TV    Electronics  40000   East
# 3   Refrigerator    Electronics  45000   West
# 4        Shampoo  Personal Care  10000  North
# 5           Soap  Personal Care   8000  South
# 6     Toothpaste  Personal Care   9000   East
# 7      Face Wash  Personal Care  12000   West
# 8           Rice        Grocery  20000  North
# 9          Wheat        Grocery  15000  South
# 10      Biscuits        Grocery  12000   East
# 11         Sugar        Grocery  18000   West
# Top 3 products:
#    Product     Category  Sales Region
# 0  Laptop  Electronics  50000  North
# 1  Mobile  Electronics  30000  South
# 2      TV  Electronics  40000   East
