# %% [markdown]
# 1. Create a 1D NumPy array of 20 random integers between 1 and 100.
# Find the minimum, maximum, mean, and standard deviation without
# using Python built-in functions — use only NumPy aggregation
# functions.

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,56,78,23,45,76,98,77,99,65,14,55,90,17,84,11,20])
a=np.min(arr)
b=np.max(arr)
c=np.mean(arr)
d=np.std(arr)
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 99
# 45.9
# 34.77772275466006
