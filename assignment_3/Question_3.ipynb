# %% [markdown]
# 3. Create a class named Employee and use a constructor (__init__) to
# initialize:
# o employee_id
# o name
# o salary
# Print the employee details

# %%
class Employee:
 def __init__(self,employee_id,name,salary):
    self.employee_id = employee_id
    self.name = name
    self.salary = salary
e = Employee("abc_123","Apoorva",50000)

print(e.employee_id,e.name,e.salary)
# Out:
# abc_123 Apoorva 50000
