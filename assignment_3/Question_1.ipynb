# %% [markdown]
# 1.     Create a class named Student with attributes:
# o name
# o age
# o course
# Create an object and print all the details.

# %%
class Student:
   name = "Apoorva"
   age = 20
   course = "AIML"
  
s = Student()
print(s.name)
print(s.age)
print(s.course)
# Out:
# Apoorva
# 20
# AIML
