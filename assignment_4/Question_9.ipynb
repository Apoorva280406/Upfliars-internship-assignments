# %% [markdown]
# 9. Write a program that:
#  ● Creates a file
#  ● Writes student data (name and marks)
#  ● Reads and displays the content

# %%
file = open("student.txt", "w")
file.write("Name: Apoorva\n")
file.write("Marks: 78\n")
file.close()
file = open("student.txt", "r")
content = file.read()
print("File Content:")
print(content)
file.close()
# Out:
# File Content:
# Name: Apoorva
# Marks: 78
